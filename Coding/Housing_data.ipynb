# %%
# Libraries and Imports
import pandas as pd
import datetime

# %%
# Read in excel file for King County housing
kc_df = pd.read_csv('../Data/kc_house_data.csv')
type(kc_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Review the DataFrame
kc_df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# Check what are the datatypes
kc_df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Update the 'date' column to datetime format
kc_df['date']= pd.to_datetime(
    kc_df['date'],
    infer_datetime_format =True,
    utc = True
)

# %%
# Convert the datetime object to just the date
kc_df['date'] = pd.to_datetime(kc_df['date']).dt.date

# Review the column
kc_df['date']
# Out:
# 0        2014-10-13
# 1        2014-12-09
# 2        2015-02-25
# 3        2014-12-09
# 4        2015-02-18
#             ...
# 21608    2014-05-21
# 21609    2015-02-23
# 21610    2014-06-23
# 21611    2015-01-16
# 21612    2014-10-15
# Name: date, Length: 21613, dtype: object

# %%
# Sort by the date column
kc_df.sort_values(by=['date'])
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190  2014-05-02   437500.0         3       2.25         1970
# 9596    472000620  2014-05-02   790000.0         3       2.50         2600
# 9587   1024069009  2014-05-02   675000.0         5       2.50         2820
# 20602  7853361370  2014-05-02   555000.0         4       2.50         3310
# 11577  5056500260  2014-05-02   440000.0         4       2.25         2160
# ...           ...         ...        ...       ...        ...          ...
# 7898   1422700040  2015-05-14   183000.0         3       1.00         1170
# 928    8730000270  2015-05-14   359000.0         2       2.75         1370
# 5637   7923600250  2015-05-15   450000.0         5       2.00         1870
# 13053  5101400871  2015-05-24   445500.0         2       1.75         1390
# 16594  9106000005  2015-05-27  1310000.0         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ### Read in the Mortgage Rate Information

# %%
# REad in the CSV with mortgage rates and convert to a DataFrame format
series =pd.read_csv('../Data/mortgage_rates.csv')
df=pd.DataFrame(series)

# %%
# Review the datatypes
df.dtypes
# Out:
# observation_date     object
# MORTGAGE30US        float64
# dtype: object

# %%
# Convert to DateTime
df['date']= pd.to_datetime(
    df['observation_date'],
    infer_datetime_format =True,
    utc = True
)

# Convert the datetime object to just the date
df['date'] = pd.to_datetime(df['date']).dt.date

# Review the DataFrame
df
# Out:
#    observation_date  MORTGAGE30US        date
# 0        2014-05-08          4.21  2014-05-08
# 1        2014-05-15          4.20  2014-05-15
# 2        2014-05-22          4.14  2014-05-22
# 3        2014-05-29          4.12  2014-05-29
# 4        2014-06-05          4.14  2014-06-05
# 5        2014-06-12          4.20  2014-06-12
# 6        2014-06-19          4.17  2014-06-19
# 7        2014-06-26          4.14  2014-06-26
# 8        2014-07-03          4.12  2014-07-03
# 9        2014-07-10          4.15  2014-07-10
# 10       2014-07-17          4.13  2014-07-17
# 11       2014-07-24          4.13  2014-07-24
# 12       2014-07-31          4.12  2014-07-31
# 13       2014-08-07          4.14  2014-08-07
# 14       2014-08-14          4.12  2014-08-14
# 15       2014-08-21          4.10  2014-08-21
# 16       2014-08-28          4.10  2014-08-28
# 17       2014-09-04          4.10  2014-09-04
# 18       2014-09-11          4.12  2014-09-11
# ...

# %%
# From Stackflow to expand weekly dates into days
df = pd.read_csv(io.StringIO("""ID  Start   Stop
1   2014-05-08  2014-05-15
2   2014-05-16  2014-05-22
"""), sep="\t", index_col=0)
df.Start = pd.to_datetime(df.Start)
df.Stop = pd.to_datetime(df.Stop)


df.assign(Date=lambda dfa: dfa.apply(lambda r: pd.date_range(r["Start"], r["Stop"]), axis=1)).explode("Date")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FRAGAT~1\AppData\Local\Temp/ipykernel_9568/3247329226.py in <module>
#       1 # From Stackflow to expand weekly dates into days
# ----> 2 df = pd.read_csv(io.StringIO("""ID  Start   Stop
#       3 1   2014-05-08  2014-05-15
#       4 2   2014-05-16  2014-05-22
#       5 """), sep="\t", index_col=0)
#
# NameError: name 'io' is not defined
